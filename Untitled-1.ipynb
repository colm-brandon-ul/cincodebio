# %%
import requests
f = open("./test-code.py", 'rb')
files = {"model": (f.name, f, "multipart/form-data")}
res = requests.post(url='http://192.168.64.2/execution-api/test/python-code/submit',files=files)

print(res.status_code)
print(res.content)
# Out:
# 202
# b'{"url":"http://192.168.64.2/frontend/65ef6178e5b014f10832a5e1"}'

# %%
# Out:
# b''

# %%
# Out:
# '{"detail":[{"loc":["query","model"],"msg":"field required","type":"value_error.missing"}]}'

# %%
res.status_code
# Out:
# 422

# %%
res = requests.get('http://192.168.64.2/services-api/openapi.json')

# %%
import requests

url = "https://example.com/api/endpoint"
headers = {
    "cdb-workflow-id": "your_workflow_id",
    "cdb-external-url": "your_external_url"
}
data = {
    "key1": "value1",
    "key2": "value2"
}

response = requests.post(url, headers=headers, json=data)

print(response.status_code)
print(response.json())

# %%
res.json()
# Out:
# {'openapi': '3.1.0',
#  'info': {'title': 'FastAPI', 'version': '0.1.0'},
#  'paths': {'/technical-variance-correction/ace-wsi': {'post': {'summary': 'Ace Wsi Submit',
#     'operationId': 'ace_wsi_submit_technical_variance_correction_ace_wsi_post',
#     'parameters': [{'name': 'cdb-workflow-id',
#       'in': 'header',
#       'required': False,
#       'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#        'title': 'Cdb-Workflow-Id'}}],
#     'requestBody': {'required': True,
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/AceWSI_Input_Request'}}}},
#     'responses': {'200': {'description': 'Successful Response',
#       'content': {'application/json': {'schema': {'$ref': '#/components/schemas/AceWSI_Input_Response'}}}},
#      '422': {'description': 'Validation Error',
#       'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}},
# ...
